# %% [markdown]
# # Solution to Session #1 Homework

# %% [markdown]
# ## Question 1
# What's the version of NumPy that you installed?

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.20.3'

# %% [markdown]
# ## Question 2
#
# What's the version of Pandas?

# %%
pd.__version__
# Out:
# '1.3.2'

# %% [markdown]
# ### Getting the data
# For this homework, we'll use the same dataset as for the next session - the car price dataset.
# Download it with:

# %% [markdown]
# wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
#
# Now read it with Pandas

# %% [markdown]
# ## Question 3
# What's the average price of BMW cars in the dataset?

# %% [markdown]
# **DataFrame**

# %%
df = pd.read_csv('data.csv')  #reading the data and creating the DataFrame

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df [
    df['Make']== 'BMW'
]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %% [markdown]
# ### Check for missing values in MSRP

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# We see that for MSRP and Make, we have no missing values. Therefore, now we can proceed with finding the mean values of the MSRP for BMW

# %%
df.groupby('Make').MSRP.mean().round(2)
# Out:
# Make
# Acura              34887.59
# Alfa Romeo         61600.00
# Aston Martin      197910.38
# Audi               53452.11
# BMW                61546.76
# Bentley           247169.32
# Bugatti          1757223.67
# Buick              28206.61
# Cadillac           56231.32
# Chevrolet          28350.39
# Chrysler           26722.96
# Dodge              22390.06
# FIAT               22670.24
# Ferrari           238218.84
# Ford               27399.27
# GMC                30493.30
# Genesis            46616.67
# HUMMER             36464.41
# Honda              26674.34
# Hyundai            24597.04
# Infiniti           42394.21
# Kia                25310.17
# Lamborghini       331567.31
# Land Rover         67823.22
# Lexus              47549.07
# Lincoln            42839.83
# Lotus              69188.28
# Maserati          114207.71
# Maybach           546221.88
# Mazda              20039.38
# McLaren           239805.00
# Mercedes-Benz      71476.23
# Mitsubishi         21240.54
# ...

# %% [markdown]
# Above we print mean of all the Make. Another shorter way is below:

# %%
round(df[df.Make == 'BMW'].MSRP.mean(),2)
# Out:
# 61546.76

# %% [markdown]
# ## Question 4
# Select a subset of cars after year 2015 (inclusive, i.e. 2015 and after). How many of them have missing values for Engine HP?

# %%
df[df['Year'] >= 2015].isnull().sum()  #Method 1
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df[df['Year'] >= 2015]['Engine HP'].isnull().sum() #Method 2: concise, pythonic
# Out:
# 51

# %% [markdown]
# ## Question 5
# * Calculate the average "Engine HP" in the dataset.
# * Use the fillna method and to fill the missing values in "Engine HP" with the mean value from the previous step.
# * Now, calcualte the average of "Engine HP" again.
# * Has it changed?
#
# Round both means before answering this questions. You can use the round function for that:
#
# ~~~json
# print(round(mean_hp_before))
# print(round(mean_hp_after))
# ~~~

# %%
round(df['Engine HP'].describe(),2)
# Out:
# count    11845.00
# mean       249.39
# std        109.19
# min         55.00
# 25%        170.00
# 50%        227.00
# 75%        300.00
# max       1001.00
# Name: Engine HP, dtype: float64

# %%
mean_EngHP=df['Engine HP'].mean()   #average Engine HP in the dataset
mean_EngHP
# Out:
# 249.38607007176

# %%
df['Engine HP'].fillna(mean_EngHP).mean()
# Out:
# 249.38607007176

# %% [markdown]
# filling NAs with 0s chnages the mean. But replacing NAs with mean values doesn't changes. That means fillna method alreday replaces the NAs with missing values.

# %%
df['Engine HP'].fillna(0).mean()
# Out:
# 249.38607007176

# %% [markdown]
# ## Question 6
# * Select all the "Rolls-Royce" cars from the dataset.
# * Select only columns "Engine HP", "Engine Cylinders", "highway MPG".
# * Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 7 rows).
# * Get the underlying NumPy array. Let's call it X.
# * Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# * Invert XTX.
# * What's the sum of all the elements of the result?

# %%
pd.unique(df['Make'])
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
df_RollsRoyce = df[df.Make == 'Rolls-Royce']

# %%
df_RollsRoyce
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls-Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls-Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
coloumns = ['Engine HP', 'Engine Cylinders', 'highway MPG']

# %%
df_RR_3cols= df_RollsRoyce[coloumns]
df_RR_3cols
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5276       563.0              12.0           21
# 5277       563.0              12.0           21
# 5278       563.0              12.0           21
# 5279       563.0              12.0           20
# 5280       563.0              12.0           20
# 5281       563.0              12.0           21
# 5282       563.0              12.0           21
# 5283       563.0              12.0           21
# 5284       563.0              12.0           21
# 7443       322.0              12.0           15
# 7444       322.0              12.0           15
# 7553       453.0              12.0           19
# 7554       453.0              12.0           19
# 7555       453.0              12.0           19
# 7556       453.0              12.0           19
# 7557       453.0              12.0           19
# ...

# %%
df_dropDupl = df_RR_3cols.drop_duplicates() ##duplicates removed from only 3 cols of the Rolls-Royce
df_dropDupl
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
type(df_dropDupl )
# Out:
# pandas.core.frame.DataFrame

# %%
# x =np.array(df_dropDupl)
X = df_dropDupl.values      # Both solutions work
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
type(X)
# Out:
# numpy.ndarray

# %%
XT= X.T  #transpose of matrix x
XT
# Out:
# array([[325., 563., 563., 563., 322., 453., 624.],
#        [  8.,  12.,  12.,  12.,  12.,  12.,  12.],
#        [ 15.,  19.,  21.,  20.,  15.,  19.,  21.]])

# %%
XTX = XT.dot(X)
XTX
# Out:
# array([[1.754801e+06, 3.965600e+04, 6.519600e+04],
#        [3.965600e+04, 9.280000e+02, 1.500000e+03],
#        [6.519600e+04, 1.500000e+03, 2.454000e+03]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 5.17815728e-05,  9.06587044e-04, -1.92984188e-03],
#        [ 9.06587044e-04,  1.05723058e-01, -8.87084092e-02],
#        [-1.92984188e-03, -8.87084092e-02,  1.05900809e-01]])

# %%
XTX_inv.sum()
# Out:
# 0.032212320677486195

# %% [markdown]
# ## Questions 7
# * Create an array y with values [1000, 1100, 900, 1200, 1000, 850, 1300]
# * Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# * What's the value of the first element of w?
#
# Note: You just implemented linear regression. We'll talk about it in the next lesson.

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])
y
# Out:
# array([1000, 1100,  900, 1200, 1000,  850, 1300])

# %%
type(y)
# Out:
# numpy.ndarray

# %%
w = XTX_inv.dot(XT).dot(y)
w
# Out:
# array([ 0.19989598, 31.02612262, 31.65378877])

# %%
w[0]
# Out:
# 0.19989598183186175

# %% [markdown]
# Note:
#
#  $ w= (X^TX)-1 X^Ty
#
#  We'll talk about it more in the next week (Machine Learning for Regression)

# %% [markdown]
# ## Bonus
# Floating point arithmetics is not exact

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# Adding the mean value doesn't change the resulting mean:

# %%
np.array([1, 2, 3, 4, 5, 6]).mean()
# Out:
# 3.5

# %%
np.array([1, 2, 3, 4, 5, 6, 3.5, 3.5, 3.5]).mean()
# Out:
# 3.5
